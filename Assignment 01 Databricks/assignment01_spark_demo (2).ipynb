# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('assignment_01').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=892183418903091#setting/sparkui/0727-123206-h2yhr15r/driver-4921627102423751386">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
user_data =[(101,"abc.123@gmail.com","hindi","mumbai"),
(102,"jhon@gmail.com","english","usa"),
(103,"madan.44@gmail.com","marathi","nagpur"),
(104,"local.88@outlook.com","tamil","chennai"),
(105,"sahil.55@gmail.com","english","usa"),
(106,"adi@gmail.com","hindi","nagpur"),
(107,"jason@gmail.com","marathi","mumbai"),
(108,"sohan@gmail.com","kannad","usa"),
(109,"case@outlook.com","tamil","mumbai"),
(110,"fury@gmail.com","hindi","nagpur")]

user_schema = ["user_id","emailid","nativelanguage","location" ]

userDF= spark.createDataFrame(data=user_data,schema=user_schema)

display(userDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>emailid</th><th>nativelanguage</th><th>location</th></tr></thead><tbody><tr><td>101</td><td>abc.123@gmail.com</td><td>hindi</td><td>mumbai</td></tr><tr><td>102</td><td>jhon@gmail.com</td><td>english</td><td>usa</td></tr><tr><td>103</td><td>madan.44@gmail.com</td><td>marathi</td><td>nagpur</td></tr><tr><td>104</td><td>local.88@outlook.com</td><td>tamil</td><td>chennai</td></tr><tr><td>105</td><td>sahil.55@gmail.com</td><td>english</td><td>usa</td></tr><tr><td>106</td><td>adi@gmail.com</td><td>hindi</td><td>nagpur</td></tr><tr><td>107</td><td>jason@gmail.com</td><td>marathi</td><td>mumbai</td></tr><tr><td>108</td><td>sohan@gmail.com</td><td>kannad</td><td>usa</td></tr><tr><td>109</td><td>case@outlook.com</td><td>tamil</td><td>mumbai</td></tr><tr><td>110</td><td>fury@gmail.com</td><td>hindi</td><td>nagpur</td></tr></tbody></table></div>

# %%
transaction_data =[(3300101,1000001,101,700,"mouse"),
(3300102,1000002,102,900,"keyboard"),
(3300103,1000003,103,34000,"tv"),
(3300104,1000004,101,35000,"fridge"),
(3300105,1000005,105,55000,"sofa"),
(3300106,1000006,106,100,"bed"),
(3300107,1000007,105,66000,"laptop"),
(3300108,1000008,108,20000,"phone"),
(3300109,1000009,101,500,"speaker"),
(3300110,1000010,102,1000,"chair")]

transaction_schema = ["transaction_id","product_id","userid","price","product_description" ]

transactionDF= spark.createDataFrame(data=transaction_data,schema=transaction_schema)

display(transactionDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>product_id</th><th>userid</th><th>price</th><th>product_description</th></tr></thead><tbody><tr><td>3300101</td><td>1000001</td><td>101</td><td>700</td><td>mouse</td></tr><tr><td>3300102</td><td>1000002</td><td>102</td><td>900</td><td>keyboard</td></tr><tr><td>3300103</td><td>1000003</td><td>103</td><td>34000</td><td>tv</td></tr><tr><td>3300104</td><td>1000004</td><td>101</td><td>35000</td><td>fridge</td></tr><tr><td>3300105</td><td>1000005</td><td>105</td><td>55000</td><td>sofa</td></tr><tr><td>3300106</td><td>1000006</td><td>106</td><td>100</td><td>bed</td></tr><tr><td>3300107</td><td>1000007</td><td>105</td><td>66000</td><td>laptop</td></tr><tr><td>3300108</td><td>1000008</td><td>108</td><td>20000</td><td>phone</td></tr><tr><td>3300109</td><td>1000009</td><td>101</td><td>500</td><td>speaker</td></tr><tr><td>3300110</td><td>1000010</td><td>102</td><td>1000</td><td>chair</td></tr></tbody></table></div>

# %%
display(userDF)
display(transactionDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th
td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>105</td><td>sahil.55@gmail.com</td><td>english</td><td>usa</td><td>3300105</td><td>1000005</td><td>105</td><td>55000</td><td>sofa</td></tr><tr><td>105</td><td>sahil.55@gmail.com</td><td>english</td><td>usa</td><td>3300107</td><td>1000007</td><td>105</td><td>66000</td><td>laptop</td></tr><tr><td>106</td><td>adi@gmail.com</td><td>hindi</td><td>nagpur</td><td>3300106</td><td>1000006</td><td>106</td><td>100</td><td>bed</td></tr><tr><td>107</td><td>jason@gmail.com</td><td>marathi</td><td>mumbai</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>108</td><td>sohan@gmail.com</td><td>kannad</td><td>usa</td><td>3300108</td><td>1000008</td><td>108</td><td>20000</td><td>phone</td></tr><tr><td>109</td><td>case@outlook.com</td><td>tamil</td><td>mumbai</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>110</td><td>fury@gmail.com</td><td>hindi</td><td>nagpur</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
#a)Count of unique locations where each product is sold.
df_join.groupby('location').count().show()
# Out:
# +--------+-----+
# |location|count|
# +--------+-----+
# | chennai|    1|
# |  nagpur|    3|
# |  mumbai|    5|
# |     usa|    5|
# +--------+-----+

# %%
#b)	Find out products bought by each user.
df_join.groupby(['user_id','product_description']).count().show()
# Out:
# +-------+-------------------+-----+
# |user_id|product_description|count|
# +-------+-------------------+-----+
# |    110|               null|    1|
# |    101|              mouse|    1|
# |    107|               null|    1|
# |    103|                 tv|    1|
# |    101|            speaker|    1|
# |    104|               null|    1|
# |    102|           keyboard|    1|
# |    106|                bed|    1|
# |    108|              phone|    1|
# |    105|               sofa|    1|
# |    102|              chair|    1|
# |    105|             laptop|    1|
# |    101|             fridge|    1|
# |    109|               null|    1|
# +-------+-------------------+-----+

# %%
productcount=df_join.groupby(['user_id','product_description']).count()
display(productcount.na.drop())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>product_description</th><th>count</th></tr></thead><tbody><tr><td>101</td><td>mouse</td><td>1</td></tr><tr><td>103</td><td>tv</td><td>1</td></tr><tr><td>101</td><td>speaker</td><td>1</td></tr><tr><td>102</td><td>keyboard</td><td>1</td></tr><tr><td>106</td><td>bed</td><td>1</td></tr><tr><td>108</td><td>phone</td><td>1</td></tr><tr><td>105</td><td>sofa</td><td>1</td></tr><tr><td>102</td><td>chair</td><td>1</td></tr><tr><td>105</td><td>laptop</td><td>1</td></tr><tr><td>101</td><td>fridge</td><td>1</td></tr></tbody></table></div>

# %%
#c)Total spending done by each user on each product.c)	Total spending done by each user on each product.
df_join.groupby(['user_id','product_description','price']).avg('price').show()
# Out:
# +-------+-------------------+-----+----------+
# |user_id|product_description|price|avg(price)|
# +-------+-------------------+-----+----------+
# |    102|           keyboard|  900|     900.0|
# |    105|               sofa|55000|   55000.0|
# |    110|               null| null|      null|
# |    101|            speaker|  500|     500.0|
# |    101|              mouse|  700|     700.0|
# |    107|               null| null|      null|
# |    101|             fridge|35000|   35000.0|
# |    104|               null| null|      null|
# |    106|                bed|  100|     100.0|
# |    103|                 tv|34000|   34000.0|
# |    105|             laptop|66000|   66000.0|
# |    102|              chair| 1000|    1000.0|
# |    109|               null| null|      null|
# |    108|              phone|20000|   20000.0|
# +-------+-------------------+-----+----------+

# %%
spendingbyuser=df_join.groupby(['user_id','product_description','price']).avg('price')
display(spendingbyuser.na.drop())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>product